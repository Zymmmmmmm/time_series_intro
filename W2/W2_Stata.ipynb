// %%
use airline, clear

// %%
summarize miles
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//        miles |         96    10385.74    2202.501       6178      16234

// %% [markdown]
// # Part (b)

// %%
summarize miles if year<1967
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//        miles |         48    9174.583    1641.828       6178      12417

// %% [markdown]
// # Part (c)

// %%
generate trend = _n

// %%
regress miles trend
// Out:
//       Source |       SS           df       MS      Number of obs   =        96
// -------------+----------------------------------   F(1, 94)        =     84.52
//        Model |   218191383         1   218191383   Prob > F        =    0.0000
//     Residual |   242654441        94  2581430.23   R-squared       =    0.4735
// -------------+----------------------------------   Adj R-squared   =    0.4679
//        Total |   460845824        95  4851008.68   Root MSE        =    1606.7
//
// ------------------------------------------------------------------------------
//        miles |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//        trend |   54.40341    5.91749     9.19   0.000      42.6541    66.15273
//        _cons |   7747.174   330.5418    23.44   0.000     7090.876    8403.473
// ------------------------------------------------------------------------------

// %%
predict pred_trend
// Out:
// (option xb assumed; fitted values)

// %%
predict errors, resid
// Out:
// (96 missing values generated)

// %%
twoway tsline miles || tsline pred_trend || tsline errors
// Out:
// This front-end cannot display the desired image type.

// %% [markdown]
// # Part (d)

// %%
summarize errors
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//       errors |         96    5.70e-06    1598.204  -3029.833   3427.309

// %%
summarize errors if month>=6 & month <=9
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//       errors |         32    1786.763    835.7308  -749.7993   3427.309

// %% [markdown]
// # Part (e)

// %%
tabulate month, generate(m)
// Out:
//       month |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |         16        8.33        8.33
//           2 |         16        8.33       16.67
//           3 |         16        8.33       25.00
//           4 |         16        8.33       33.33
//           5 |         16        8.33       41.67
//           6 |         16        8.33       50.00
//           7 |         16        8.33       58.33
//           8 |         16        8.33       66.67
//           9 |         16        8.33       75.00
//          10 |         16        8.33       83.33
//          11 |         16        8.33       91.67
//          12 |         16        8.33      100.00
// ------------+-----------------------------------
//       Total |        192      100.00

// %%
regress miles trend m2 m3 m4 m5 m6 m7 m8 m9 m10 m11 m12
// Out:
//       Source |       SS           df       MS      Number of obs   =        96
// -------------+----------------------------------   F(12, 83)       =     66.58
//        Model |   417475712        12  34789642.7   Prob > F        =    0.0000
//     Residual |    43370112        83   522531.47   R-squared       =    0.9059
// -------------+----------------------------------   Adj R-squared   =    0.8923
//        Total |   460845824        95  4851008.68   Root MSE        =    722.86
//
// ------------------------------------------------------------------------------
//        miles |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//        trend |   52.96057   2.683241    19.74   0.000     47.62371    58.29742
//           m2 |  -513.4606   361.4417    -1.42   0.159    -1232.353    205.4323
//           m3 |   1189.579   361.4715     3.29   0.001     470.6265    1908.531
// ...

// %%
predict pred_seas
// Out:
// (option xb assumed; fitted values)

// %%
tsline miles pred_trend pred_seas
// Out:
// This front-end cannot display the desired image type.

// %%
!rm -rf W2_Stata.html
!jupyter nbconvert --to html W2_Stata.ipynb
// Out:
// [NbConvertApp] Converting notebook W2_Stata.ipynb to html
// [NbConvertApp] Writing 750452 bytes to W2_Stata.html
