// %%
use "~/Dropbox/Working_Directory/Tex_MD/Teaching/tutorial/6003/W3/cpi.dta", clear

// %%
ac cpi
// Out:
// This front-end cannot display the desired image type.

// %%
tsline cpi
// Out:
// This front-end cannot display the desired image type.

// %%
generate infl=s12.cpi/l12.cpi
// Out:
// (12 missing values generated)

// %%
ac infl, lags(40)
// Out:
// This front-end cannot display the desired image type.

// %%
tsline infl
// Out:
// This front-end cannot display the desired image type.

// %%
!rm -rf W3_Stata.html
!jupyter nbconvert --to html W3_Stata.ipynb
// Out:
// [NbConvertApp] Converting notebook W3_Stata.ipynb to html
// [NbConvertApp] Writing 775811 bytes to W3_Stata.html
